# %%
# Программа для формирования базы данных текстов статей с тегами, размещенных на сайте https://tass.ru/ по тегам

# %%
import requests
from fake_useragent import UserAgent
import re
import time
import random

# %%
def get_article_url_list (contry = 'venesuela', iter_number= 3):    
    date = '2024-09-30T15:05:01.994964'
    article_url_list =[]
    params = {        
        'user-agent': UserAgent().random       
    }
    for iter in range(1,iter_number):
        try:
            # Мали url = 'https://tass.ru/tbp/api/v1/content?limit=11&last_es_updated_dt={}&lang=ru&exclude_types=press_center&tags=/mali&sort=-es_updated_dt'.format(date)
            url = 'https://tass.ru/tbp/api/v1/content?limit=11&last_es_updated_dt={}&lang=ru&exclude_types=press_center&tags=/{}&sort=-es_updated_dt'.format(date, contry) 
         
            res = requests.get(url, data=params)
            #print(res.json())
            print('Извлечение url, {} итерация'.format(iter))
            for item in res.json()["result"]:
                #print('https://tass.ru'+item["url"])
                article_url_list.append('https://tass.ru'+item["url"])
                date = item["es_updated_dt"]
            time.sleep(random.randrange(3, 8))    
        except Exception as ex:
            print(ex)
        
    return article_url_list

# %%
import string

def remove_chars_from_text(text, chars):
    # return "".join([ch for ch in text if ch not in chars])
    content = ''
    for ch in text:
        if ch not in chars:
            content = content + ''.join(ch)
        else:
            content = content + ''.join(' ')
    return content

import re

def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)
spec_chars = string.punctuation + '\r' + '\n\xa0«»\t—…'

# %%
def get_text(r):
    # Извлечение текста из статьи
    #article_title - Название статьи
    #article_text - Текст статьи без ссылок
    #article_tags - метки статьи
   
    from bs4 import BeautifulSoup
    import re
    article_tags = []
    article_text = ''
    soup = BeautifulSoup(r.text, 'lxml')
    article_title = soup.find('h1', {'class': 'NewsHeader_titles__uKY5F'}).text
    article_body = soup.find_all('p', {'class': 'Paragraph_paragraph__9WAFK'})
    tags_item = soup.find_all('a', {'class': 'Tags_tag__o7Dqc'})     
    #print (article_title)
    #print (article_body)
    #print (tags_item)
    for item in article_body:
        soup_temp = BeautifulSoup(item.text, 'lxml')
        text_post = re.sub(r'https?:\/\/.*[\r\n]*', '', soup_temp.text, flags=re.MULTILINE)
        text_post = remove_emojis(text_post)
        text_post = re.sub('\n\n', '\n', text_post, flags=re.MULTILINE)
        article_text = article_text + '\n'+ text_post    
    article_tags= [p.text for p in tags_item]    
    head_post, sep, article_text = article_text.partition('/ТАСС/.') # Удаление заголовка .../ТАСС/.
    return article_title, article_text, article_tags

# %%
def get_article(article_url, contry='venesuela'):
    import requests
    from fake_useragent import UserAgent
    import random
    import time
    from bs4 import BeautifulSoup
    url = article_url
    useragent = {'User-Agent': UserAgent().random}
    try:
        r = requests.get(url, headers=useragent)
        time.sleep(random.randrange(1, 6))
        article_title, article_text, article_tags = get_text(r)
        #print(article_title)       
        #print(article_text)
        #print(article_tags)
        # Запись в файл        
        try:
            with open('./Tass_Dataset_tag/{}/tass_{}.txt'.format( contry, re.search(r'(\d+)', url).group(1)), "w", encoding="utf-8") as some_file:
                print("\n\n".join([article_title, article_text]), file=some_file)
                some_file.close()
            with open('./Tass_Dataset_tag/tag/{}/tass_{}.txt'.format( contry, re.search(r'(\d+)', url).group(1)), "w", encoding="utf-8") as some_file:
                print("\n\n".join(article_tags), file=some_file)
                some_file.close()                
        except Exception as ex:
            print(ex)
    except Exception as ex:
        print(ex)
    return

# %%
#article_url_list = get_article_url_list(20)

# %%
#article_url_list[:10]

# %%
#len(article_url_list)

# %%
#for article_url in article_url_list:
#    get_article(article_url)

# %%
#Afrika_tags = [ 'kitay', 'chad', 'gana', 'pakistan', 'vetnam', 'laos']
#Afrika_tags = [ 'alzhir', 'burkina-faso', 'egipet', 'gvineya', 'mali', 'niger', 'senegal', 'siriya', 'tunis', 'venesuela', 'zimbabve']
#Afrika_tags = [ 'boliviya', 'braziliya', 'yuar', 'indiya', 'burundi', 'ruanda']
#Afrika_tags = [  'afganistan', 'kndr', 'mongoliya', 'respublika-koreya', 'chili']
#Afrika_tags = [ 'bangladesh', 'benin', 'gabon', 'ekvatorialnaya-gviney', 'keniya', 'indoneziya']
#Afrika_tags = [ 'iordaniya', 'irak', 'kambodzha', 'kuba', 'tailand', 'efiopiya']
#Afrika_tags = [ 'urugvay', 'turciya', 'kamerun', 'madagaskar', 'mozambik', 'yaponiya']
#Afrika_tags = [ 'sudan','oae' ]
#Afrika_tags = [ 'marokko', 'kongo-drk', 'kongo-rk']
Afrika_tags = [ 'angola', 'belorussiya', 'litva', 'franciya', 'botsvana', 'vengriya',
               'italiya', 'germaniya' , 'palestina', 'izrail', 'tayvan', 'tanzaniya',
              'ispaniya', 'колумбия', 'livan', 'oman','paragvay', 'peru', 'portugaliya',
               'ssha'
              ]
import os
for country in Afrika_tags:

    if not os.path.exists('./Tass_Dataset_tag/{}'.format(country)):
        os.makedirs('./Tass_Dataset_tag/{}'.format(country))
    if not os.path.exists('./Tass_Dataset_tag/tag/{}'.format(country)):
        os.makedirs('./Tass_Dataset_tag/tag/{}'.format(country))       
    
    article_url_list = get_article_url_list(country, 20)
    print(article_url_list[:10])
    for article_url in article_url_list:
        get_article(article_url, country)
    time.sleep(random.randrange(100, 300))
# Out:
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21946989', 'https://tass.ru/armiya-i-opk/21841127', 'https://tass.ru/armiya-i-opk/21825923', 'https://tass.ru/ekonomika/21817675', 'https://tass.ru/mezhdunarodnaya-panorama/21752059', 'https://tass.ru/ekonomika/21752605', 'https://tass.ru/mezhdunarodnaya-panorama/21752365', 'https://tass.ru/mezhdunarodnaya-panorama/21752305', 'https://tass.ru/ekonomika/21717613', 'https://tass.ru/ekonomika/21584609']
# C:\Users\user\AppData\Local\Temp\ipykernel_11496\118503635.py:19: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup_temp = BeautifulSoup(item.text, 'lxml')
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21998363', 'https://tass.ru/ekonomika/21996813', 'https://tass.ru/mezhdunarodnaya-panorama/21996537', 'https://tass.ru/proisshestviya/21995211', 'https://tass.ru/ekonomika/21995167', 'https://tass.ru/mezhdunarodnaya-panorama/21994153', 'https://tass.ru/kultura/21991541', 'https://tass.ru/ekonomika/21988629', 'https://tass.ru/ekonomika/21988579', 'https://tass.ru/ekonomika/21988411']
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21998363', 'https://tass.ru/ekonomika/21997309', 'https://tass.ru/mezhdunarodnaya-panorama/21996589', 'https://tass.ru/obschestvo/21975869', 'https://tass.ru/mezhdunarodnaya-panorama/21973593', 'https://tass.ru/obschestvo/21967991', 'https://tass.ru/ekonomika/21961389', 'https://tass.ru/mezhdunarodnaya-panorama/21955281', 'https://tass.ru/mezhdunarodnaya-panorama/21953409', 'https://tass.ru/mezhdunarodnaya-panorama/21953395']
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21997775', 'https://tass.ru/proisshestviya/21998731', 'https://tass.ru/mezhdunarodnaya-panorama/21997953', 'https://tass.ru/nauka/21997043', 'https://tass.ru/mezhdunarodnaya-panorama/21993703', 'https://tass.ru/mezhdunarodnaya-panorama/21993523', 'https://tass.ru/mezhdunarodnaya-panorama/21992981', 'https://tass.ru/mezhdunarodnaya-panorama/21989673', 'https://tass.ru/politika/21986115', 'https://tass.ru/mezhdunarodnaya-panorama/21985617']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/obschestvo/21977245', 'https://tass.ru/obschestvo/21877155', 'https://tass.ru/mezhdunarodnaya-panorama/21860111', 'https://tass.ru/obschestvo/21661223', 'https://tass.ru/mezhdunarodnaya-panorama/21236817', 'https://tass.ru/mezhdunarodnaya-panorama/21193853', 'https://tass.ru/ekonomika/21017235', 'https://tass.ru/ekonomika/20930329', 'https://tass.ru/mezhdunarodnaya-panorama/20576397', 'https://tass.ru/mezhdunarodnaya-panorama/20545471']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/22000357', 'https://tass.ru/mezhdunarodnaya-panorama/21999751', 'https://tass.ru/mezhdunarodnaya-panorama/21999647', 'https://tass.ru/mezhdunarodnaya-panorama/21998101', 'https://tass.ru/mezhdunarodnaya-panorama/21993523', 'https://tass.ru/mezhdunarodnaya-panorama/21991989', 'https://tass.ru/kosmos/21982205', 'https://tass.ru/mezhdunarodnaya-panorama/21982179', 'https://tass.ru/mezhdunarodnaya-panorama/21982325', 'https://tass.ru/mezhdunarodnaya-panorama/21982183']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21994733', 'https://tass.ru/politika/21969615', 'https://tass.ru/mezhdunarodnaya-panorama/21965559', 'https://tass.ru/ekonomika/21949289', 'https://tass.ru/ekonomika/21949229', 'https://tass.ru/mezhdunarodnaya-panorama/21948309', 'https://tass.ru/mezhdunarodnaya-panorama/21945783', 'https://tass.ru/mezhdunarodnaya-panorama/21936281', 'https://tass.ru/proisshestviya/21932883', 'https://tass.ru/mezhdunarodnaya-panorama/21926043']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/ekonomika/21997047', 'https://tass.ru/mezhdunarodnaya-panorama/21996459', 'https://tass.ru/proisshestviya/21995331', 'https://tass.ru/mezhdunarodnaya-panorama/21993801', 'https://tass.ru/ekonomika/21994077', 'https://tass.ru/ekonomika/21993429', 'https://tass.ru/mezhdunarodnaya-panorama/21991153', 'https://tass.ru/mezhdunarodnaya-panorama/21991025', 'https://tass.ru/mezhdunarodnaya-panorama/21990247', 'https://tass.ru/mezhdunarodnaya-panorama/21989943']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21998715', 'https://tass.ru/mezhdunarodnaya-panorama/21996733', 'https://tass.ru/mezhdunarodnaya-panorama/21992917', 'https://tass.ru/mezhdunarodnaya-panorama/21992717', 'https://tass.ru/mezhdunarodnaya-panorama/21992555', 'https://tass.ru/mezhdunarodnaya-panorama/21992525', 'https://tass.ru/mezhdunarodnaya-panorama/21992111', 'https://tass.ru/mezhdunarodnaya-panorama/21991825', 'https://tass.ru/obschestvo/21991485', 'https://tass.ru/mezhdunarodnaya-panorama/21989683']
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/22000851', 'https://tass.ru/mezhdunarodnaya-panorama/22000107', 'https://tass.ru/obschestvo/21999881', 'https://tass.ru/blizhnevostochnyy-konflikt/21999845', 'https://tass.ru/mezhdunarodnaya-panorama/21999267', 'https://tass.ru/mezhdunarodnaya-panorama/21999229', 'https://tass.ru/mezhdunarodnaya-panorama/21998715', 'https://tass.ru/mezhdunarodnaya-panorama/21995905', 'https://tass.ru/mezhdunarodnaya-panorama/21997343', 'https://tass.ru/mezhdunarodnaya-panorama/21997291']
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21999745', 'https://tass.ru/mezhdunarodnaya-panorama/21997429', 'https://tass.ru/proisshestviya/21996899', 'https://tass.ru/mezhdunarodnaya-panorama/21994585', 'https://tass.ru/mezhdunarodnaya-panorama/21994489', 'https://tass.ru/mezhdunarodnaya-panorama/21992535', 'https://tass.ru/mezhdunarodnaya-panorama/21990973', 'https://tass.ru/mezhdunarodnaya-panorama/21990827', 'https://tass.ru/obschestvo/21987127', 'https://tass.ru/mezhdunarodnaya-panorama/21981637']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/ekonomika/21978051', 'https://tass.ru/kultura/21870147', 'https://tass.ru/mezhdunarodnaya-panorama/21849177', 'https://tass.ru/ekonomika/21832115', 'https://tass.ru/proisshestviya/21806937', 'https://tass.ru/obschestvo/21708119', 'https://tass.ru/ekonomika/21689417', 'https://tass.ru/mezhdunarodnaya-panorama/21582339', 'https://tass.ru/obschestvo/21579265', 'https://tass.ru/obschestvo/21485171']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Expecting value: line 1 column 1 (char 0)
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/obschestvo/21975527', 'https://tass.ru/mezhdunarodnaya-panorama/21973689', 'https://tass.ru/obschestvo/21973937', 'https://tass.ru/ekonomika/21964119', 'https://tass.ru/mezhdunarodnaya-panorama/21959227', 'https://tass.ru/ekonomika/21954895', 'https://tass.ru/obschestvo/21954701', 'https://tass.ru/ekonomika/21952289', 'https://tass.ru/mezhdunarodnaya-panorama/21950161', 'https://tass.ru/mezhdunarodnaya-panorama/21945527']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# []
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# Expecting value: line 1 column 1 (char 0)
# ['https://tass.ru/mezhdunarodnaya-panorama/22000851', 'https://tass.ru/mezhdunarodnaya-panorama/21999267', 'https://tass.ru/mezhdunarodnaya-panorama/21998715', 'https://tass.ru/ekonomika/21997133', 'https://tass.ru/mezhdunarodnaya-panorama/21995905', 'https://tass.ru/mezhdunarodnaya-panorama/21997343', 'https://tass.ru/mezhdunarodnaya-panorama/21997291', 'https://tass.ru/mezhdunarodnaya-panorama/21997151', 'https://tass.ru/mezhdunarodnaya-panorama/21996681', 'https://tass.ru/mezhdunarodnaya-panorama/21994741']
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Expecting value: line 1 column 1 (char 0)
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/politika/21997251', 'https://tass.ru/mezhdunarodnaya-panorama/21990185', 'https://tass.ru/obschestvo/21989871', 'https://tass.ru/ekonomika/21878221', 'https://tass.ru/ekonomika/21820995', 'https://tass.ru/politika/21797353', 'https://tass.ru/ekonomika/21705647', 'https://tass.ru/mezhdunarodnaya-panorama/21704097', 'https://tass.ru/ekonomika/21585081', 'https://tass.ru/mezhdunarodnaya-panorama/21570969']
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/proisshestviya/21639103', 'https://tass.ru/ekonomika/21585081', 'https://tass.ru/mezhdunarodnaya-panorama/21564723', 'https://tass.ru/mezhdunarodnaya-panorama/21492417', 'https://tass.ru/mezhdunarodnaya-panorama/21472919', 'https://tass.ru/mezhdunarodnaya-panorama/21409037', 'https://tass.ru/mezhdunarodnaya-panorama/21408027', 'https://tass.ru/sport/21316725', 'https://tass.ru/politika/21095545', 'https://tass.ru/info/21069153']
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/proisshestviya/21971621', 'https://tass.ru/mezhdunarodnaya-panorama/21971489', 'https://tass.ru/proisshestviya/21881835', 'https://tass.ru/proisshestviya/21880841', 'https://tass.ru/mezhdunarodnaya-panorama/21843997', 'https://tass.ru/info/21843159', 'https://tass.ru/mezhdunarodnaya-panorama/21842145', 'https://tass.ru/mezhdunarodnaya-panorama/21761505', 'https://tass.ru/obschestvo/21676197', 'https://tass.ru/mezhdunarodnaya-panorama/21656625']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/mezhdunarodnaya-panorama/21974247', 'https://tass.ru/proisshestviya/21914645', 'https://tass.ru/obschestvo/21895521', 'https://tass.ru/proisshestviya/21888661', 'https://tass.ru/proisshestviya/21886787', 'https://tass.ru/proisshestviya/21883279', 'https://tass.ru/politika/21860139', 'https://tass.ru/ekonomika/21755379', 'https://tass.ru/mezhdunarodnaya-panorama/21742581', 'https://tass.ru/proisshestviya/21728575']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# Извлечение url, 1 итерация
# Извлечение url, 2 итерация
# Извлечение url, 3 итерация
# Извлечение url, 4 итерация
# Извлечение url, 5 итерация
# Извлечение url, 6 итерация
# Извлечение url, 7 итерация
# Извлечение url, 8 итерация
# Извлечение url, 9 итерация
# Извлечение url, 10 итерация
# Извлечение url, 11 итерация
# Извлечение url, 12 итерация
# Извлечение url, 13 итерация
# Извлечение url, 14 итерация
# Извлечение url, 15 итерация
# Извлечение url, 16 итерация
# Извлечение url, 17 итерация
# Извлечение url, 18 итерация
# Извлечение url, 19 итерация
# ['https://tass.ru/ekonomika/22000801', 'https://tass.ru/mezhdunarodnaya-panorama/21998557', 'https://tass.ru/mezhdunarodnaya-panorama/21999587', 'https://tass.ru/ekonomika/21998047', 'https://tass.ru/mezhdunarodnaya-panorama/21995905', 'https://tass.ru/mezhdunarodnaya-panorama/21997479', 'https://tass.ru/ekonomika/21997459', 'https://tass.ru/ekonomika/21997001', 'https://tass.ru/mezhdunarodnaya-panorama/21996699', 'https://tass.ru/obschestvo/21996643']
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
