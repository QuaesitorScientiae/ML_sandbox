# %%
# Программа для очистки БД текстов по странам с использованием модели (contry_post-model_ngram_rf_RandomForest.bin)

# %%
import string

def remove_chars_from_text(text, chars):
    # return "".join([ch for ch in text if ch not in chars])
    content = ''
    for ch in text:
        if ch not in chars:
            content = content + ''.join(ch)
        else:
            content = content + ''.join(' ')
    return content

import re

def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)
spec_chars = string.punctuation + '\r' + '\n\xa0«»\t—…'

# %%
def predict_contry (Text_post):
    from sklearn.ensemble import RandomForestClassifier
    from sklearn.feature_extraction.text import CountVectorizer
    from sklearn.model_selection import cross_val_score
    import pickle

    ngram_replace = True # использование замены в тексте ngram
    
    with open('contry_post-model_ngram_rf_RandomForest_V3_015_03-10-2024.bin', 'rb') as f_out:
        rf_RandomForest, vocabl=pickle.load( f_out)
    x_temp = []
    content = str(Text_post).lower()  
    content = remove_emojis(content)
    content = remove_chars_from_text(content, spec_chars)
    content = remove_chars_from_text(content, string.digits)
    for i in range(1, 10):
        content = content.replace('  ', ' ')    
    x_temp.append(content)



    count = CountVectorizer(ngram_range=(1,2), vocabulary = vocabl)
    X_t = count.transform(x_temp)
    accuracy = rf_RandomForest.predict_proba(X_t)
    ix = accuracy.argmax(1).item()
    # print(f'predicted class = {log_clf.classes_[ix]} and confidence = {accuracy[0,ix]:.2%}')
    predicted_class =rf_RandomForest.classes_[ix]
    confidence = accuracy[0,ix]    
    return predicted_class, confidence

# %%
import os
import tarfile
import urllib.request


country_name_rus = {"Afganistan":'Афганистан',"China":'КНР',"CAR":'Центрально-Африканская Республика',
                    "Ethiopia":"Эфиопия ","India":'Индия', "Iran":'Иран',"KNDR":'КНДР', "Libya":'Ливия',
                    "Morocco":'Морокко', "Sudan":'Судан', "Syria":'Сирия', "Turkey":'Турция',
                    "Argentina":'Аргентина', "DRK_Congo":'ДРК (Конго)', "Burkina Faso":'Буркина-Фасо',
                    "Niger":'Нигер', "Mali":'Мали', "Senegal":'Сенегал', "Egipet":'Египет', "Gvineya":'Гвинея',
                    "Venesuela":'Венесуэла', "Algeria":'Алжир', "Zimbabve":'Зимбабве', "Tunis":'Тунис',
                    "Boliviya":'Боливия', "Braziliya":'Бразилия', "Yuar":'ЮАР', "Burundi":'Бурунди',
                    "Ruanda":'Руанда', "Mongoliya":'Монголия', "Respublika-koreya": 'Южная Корея',
                    "Chili": 'Чили',  'Bangladesh':'Бангладеш', 'Benin':'Бенин', 'Gabon':'Габон',
                    'Ekvatorialnaya-gviney':'Экваториальная Гвинея', 'Keniya':'Кения',
                    'Indoneziya':'Индонезия','Iordaniya':'Иордания', 'Irak':'Ирак',
                    'Kambodzha':'Камбоджа', 'Kuba':'Куба', 'Tailand':'Таиланд', 'Urugvay':'Уругвай',
                    'Kamerun':'Камерун', 'Madagaskar':'Мадагаскар', 'Mozambik':'Мозамбик', 'Chad':'Чад',
                    'Yaponiya':'Япония', 'Mexico': 'Мексика', 'Laos': 'Лаос', 'Pakistan': 'Пакистан', 
                    'Oae': 'ОАЭ', 'Saudovskaya_araviya': 'Саудовская Аравия','Yemen':'Йемен', 'RK_Congo':'Республика Конго'
                   }

CL =[ "Afganistan","China","CAR", "Ethiopia",
      "India", "Iran","KNDR", "Libya", "Morocco", "Sudan",
      "Syria", "Turkey", "Argentina", "DRK_Congo", "Burkina Faso",
      "Niger", "Mali", "Senegal", "Egipet", "Gvineya", "Venesuela",
      "Algeria", "Zimbabve", "Tunis", "Boliviya", "Braziliya",
      "Yuar", "Burundi", "Ruanda", "Mongoliya", 'Pakistan', 
     "Chili", 'Bangladesh', 'Benin', 'Gabon', 'Laos', 'Chad' , 
     'Keniya', 'Indoneziya','Iordaniya', 'Irak', 'Kambodzha', 'Kuba',
     'Tailand','Urugvay', 'Kamerun', 'Madagaskar', 'Mozambik', 'Yaponiya',
     'Mexico', 'Oae','Saudovskaya_araviya', 'Yemen', 'Pakistan', 'Laos', 'RK_Congo'
    ]

DIR_PATH= {}
DOWNLOAD_ROOT = "D:/ML/"
print(DOWNLOAD_ROOT)
#DATASET_PATH = os.path.join("datasets", "Countries")
DATASET_PATH = os.path.join("datasets", "Countries_V3")

for item in CL:
    DIR_PATH[country_name_rus[item]] = os.path.join(DATASET_PATH, item)
    
filenames = {}
for items in DIR_PATH.keys():   
    filenames[items] = [name for name in sorted(os.listdir(DIR_PATH[items])) ] 
    print(items)
# Out:
# D:/ML/
# Афганистан
# КНР
# Центрально-Африканская Республика
# Эфиопия
# Индия
# Иран
# КНДР
# Ливия
# Морокко
# Судан
# Сирия
# Турция
# Аргентина
# ДРК (Конго)
# Буркина-Фасо
# Нигер
# Мали
# Сенегал
# Египет
# Гвинея
# Венесуэла
# Алжир
# Зимбабве
# Тунис
# Боливия
# Бразилия
# ЮАР
# Бурунди
# Руанда
# Монголия
# Пакистан
# Чили
# Бангладеш
# Бенин
# Габон
# Лаос
# Чад
# Кения
# Индонезия
# Иордания
# Ирак
# Камбоджа
# Куба
# Таиланд
# Уругвай
# Камерун
# Мадагаскар
# Мозамбик
# Япония
# Мексика
# ОАЭ
# Саудовская Аравия
# Йемен
# Республика Конго

# %%
stemming=True # Stemming control
if stemming:
    from nltk.stem.snowball import SnowballStemmer
    stemmer = SnowballStemmer("russian")

# %%
ru_stopwords = set(
        """
    а авось ага агу аж ай али алло ау ах ая
    б будем будет будете будешь буду будут будучи будь будьте бы был была были было
    быть бац без безусловно бишь благо благодаря ближайшие близко более больше
    будто бывает бывала бывали бываю бывают бытует
    в вам вами вас весь во вот все всё всего всей всем всём всеми всему всех всею
    всея всю вся вы ваш ваша ваше ваши вдали вдобавок вдруг ведь везде вернее
    взаимно взаправду видно вишь включая вместо внакладе вначале вне вниз внизу
    вновь вовсе возможно воистину вокруг вон вообще вопреки вперекор вплоть
    вполне вправду вправе впрочем впрямь вресноту вроде вряд всегда всюду
    всякий всякого всякой всячески вчеред
    г го где гораздо гав
    д да для до дабы давайте давно давным даже далее далеко дальше данная
    данного данное данной данном данному данные данный данных дану данунах
    даром де действительно довольно доколе доколь долго должен должна
    должно должны должный дополнительно другая другие другим другими
    других другое другой
    е его едим едят ее её ей ел ела ем ему емъ если ест есть ешь еще ещё ею едва
    ежели еле
    ж же
    з за затем зато зачем здесь значит зря
    и из или им ими имъ их ибо иль имеет имел имела имело именно иметь иначе
    иногда иным иными итак ишь
    й
    к как кем ко когда кого ком кому комья которая которого которое которой котором
    которому которою которую которые который которым которыми которых кто ка кабы
    каждая каждое каждые каждый кажется казалась казались казалось казался казаться
    какая какие каким какими каков какого какой какому какою касательно кой коли
    коль конечно короче кроме кстати ку куда
    л ли либо лишь любая любого любое любой любом любую любыми любых
    м меня мне мной мною мог моги могите могла могли могло могу могут мое моё моего
    моей моем моём моему моею можем может можете можешь мои мой моим моими моих
    мочь мою моя мы мало меж между менее меньше мимо многие много многого многое
    многом многому можно мол му
    н на нам нами нас наса наш наша наше нашего нашей нашем нашему нашею наши нашим
    нашими наших нашу не него нее неё ней нем нём нему нет нею ним ними них но
    наверняка наверху навряд навыворот над надо назад наиболее наизворот
    наизнанку наипаче накануне наконец наоборот наперед наперекор наподобие
    например напротив напрямую насилу настоящая настоящее настоящие настоящий
    насчет нате находиться начала начале неважно негде недавно недалеко незачем
    некем некогда некому некоторая некоторые некоторый некоторых некто некуда
    нельзя немногие немногим немного необходимо необходимости необходимые
    необходимым неоткуда непрерывно нередко несколько нету неужели нечего
    нечем нечему нечто нешто нибудь нигде ниже низко никак никакой никем
    никогда никого никому никто никуда ниоткуда нипочем ничего ничем ничему
    ничто ну нужная нужно нужного нужные нужный нужных ныне нынешнее нынешней
    нынешних нынче
    о об один одна одни одним одними одних одно одного одной одном одному одною
    одну он она оне они оно от оба общую обычно ого однажды однако ой около оный
    оп опять особенно особо особую особые откуда отнелижа отнелиже отовсюду
    отсюда оттого оттот оттуда отчего отчему ох очевидно очень ом
    п по при паче перед под подавно поди подобная подобно подобного подобные
    подобный подобным подобных поелику пожалуй пожалуйста позже поистине
    пока покамест поколе поколь покуда покудова помимо понеже поприще пор
    пора посему поскольку после посреди посредством потом потому потомушта
    похожем почему почти поэтому прежде притом причем про просто прочего
    прочее прочему прочими проще прям пусть
    р ради разве ранее рано раньше рядом
    с сам сама сами самим самими самих само самого самом самому саму свое своё
    своего своей своем своём своему своею свои свой своим своими своих свою своя
    себе себя собой собою самая самое самой самый самых сверх свыше се сего сей
    сейчас сие сих сквозь сколько скорее скоро следует слишком смогут сможет
    сначала снова со собственно совсем сперва спокону спустя сразу среди сродни
    стал стала стали стало стать суть сызнова
    та то ту ты ти так такая такие таким такими таких такого такое такой таком такому такою
    такую те тебе тебя тем теми тех тобой тобою того той только том томах тому
    тот тою также таки таков такова там твои твоим твоих твой твоя твоё
    теперь тогда тоже тотчас точно туда тут тьфу тая
    у уже увы уж ура ух ую
    ф фу
    х ха хе хорошо хотел хотела хотелось хотеть хоть хотя хочешь хочу хуже
    ч чего чем чём чему что чтобы часто чаще чей через чтоб чуть чхать чьим
    чьих чьё чё
    ш ша
    щ ща щас
    ы ых ые ый
    э эта эти этим этими этих это этого этой этом этому этот этою эту эдак эдакий
    эй эка экий этак этакий эх
    ю
    я явно явных яко якобы якоже
    
    и что не это  быть этот это свой как - этот весь быть что ▫ но г. % 
    afgbezparandzhi argentinarusa irandezhurniy info raspp аль
    """.split()
    )

# %%
from charset_normalizer import from_path
import string

def remove_chars_from_text(text, chars):
    # return "".join([ch for ch in text if ch not in chars])
    content = ''
    for ch in text:
        if ch not in chars:
            content = content + ''.join(ch)
        else:
            content = content + ''.join(' ')
    return content

import re

def remove_emojis(data):
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)
spec_chars = string.punctuation + '\r' + '\n\xa0«»\t—…' 

x_temp = []
y_temp = []
predict_class = []
confidence = []
filename = []
for item in filenames.keys():
    post_temp=[]
    for names in filenames[item]:
        content = str(from_path(DIR_PATH[item]+"\\"+names).best()).lower()  
        content = remove_emojis(content)
        # content = re.sub(r'(\\u[0-9A-Fa-f]+)', lambda matchobj: chr(int(matchobj.group(0)[2:], 16)), content)
        content = remove_chars_from_text(content, spec_chars)
        content = remove_chars_from_text(content, string.digits)
        for i in range(1, 10):
            content = content.replace('  ', ' ')
        filtered_words = []
        for token in content.split():
            if token not in ru_stopwords and len(token)>2:
                if stemming and token is not None:
                    filtered_words.append(stemmer.stem(token))
                    #print('{} -{}'.format(token,stemmer.stem(token)))
                else:
                    filtered_words.append(token)
                      
        content = ' '.join(filtered_words)        
        predicted_class = "None"
        confidence_class = 0.
        try:
            if content != '':
                predicted_class, confidence_class = predict_contry (content)
                #print('predicted_class = {}, confidence_class = {:.0f}%'.format(predicted_class, confidence_class*100))
                #if predicted_class != item or confidence_class <0.2:
                #    print(content)
        except Exception as ex:
            print(ex)   
            

        x_temp.append(content)
        y_temp.append(item)
        predict_class.append(predicted_class)
        confidence.append(confidence_class)
        filename.append(names)

# %%
len(x_temp)
# Out:
# 14686

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {'Content':x_temp, 'Country':y_temp, 'Predict_class':predict_class, 'Confidence': confidence,'filename': filename }
df = pd.DataFrame(data, columns = ['Content', 'Country', 'Predict_class', 'Confidence', 'filename'])

# %%
target = 0.6

# %%
import os
for country in CL:

    if not os.path.exists('./datasets/Tass_Dataset_6/{}'.format(country)):
        os.makedirs('./datasets/Tass_Dataset_6/{}'.format(country))
    Selection_by_country = df[(df['Country']==country_name_rus[country])]    
    tail = Selection_by_country[(Selection_by_country['Country']==Selection_by_country['Predict_class']) & (Selection_by_country['Confidence']>target)].sort_values('Confidence', ascending=False) 
    print ('{}, Исходное количество тексков: {} шт., оставшееся {} шт.'.format(country_name_rus[country], Selection_by_country.shape[0], tail.shape[0])) 
    #print(tail)
    #print(tail['Content'][167])        
    #print(tail.index.get_level_values(0))
    for item in tail.index.get_level_values(0): 
        #print(tail['Content'][item])
        #print(tail['filename'][item])
        #print('./datasets/Countries_V1/{}/{}'.format(country, tail['filename'][item]))
        try:
            with open('./datasets/Tass_Dataset_6/{}/{}'.format(country, tail['filename'][item]), "w", encoding="utf-8") as some_file:
                print(tail['Content'][item], file=some_file)
                some_file.close()          
        except Exception as ex:
            print(ex)
# Out:
# Афганистан, Исходное количество тексков: 417 шт., оставшееся 380 шт.
# КНР, Исходное количество тексков: 2212 шт., оставшееся 2110 шт.
# Центрально-Африканская Республика, Исходное количество тексков: 444 шт., оставшееся 402 шт.
# Эфиопия , Исходное количество тексков: 197 шт., оставшееся 175 шт.
# Индия, Исходное количество тексков: 1232 шт., оставшееся 1150 шт.
# Иран, Исходное количество тексков: 555 шт., оставшееся 487 шт.
# КНДР, Исходное количество тексков: 284 шт., оставшееся 275 шт.
# Ливия, Исходное количество тексков: 267 шт., оставшееся 186 шт.
# Морокко, Исходное количество тексков: 597 шт., оставшееся 404 шт.
# Судан, Исходное количество тексков: 323 шт., оставшееся 187 шт.
# Сирия, Исходное количество тексков: 82 шт., оставшееся 47 шт.
# Турция, Исходное количество тексков: 973 шт., оставшееся 936 шт.
# Аргентина, Исходное количество тексков: 122 шт., оставшееся 87 шт.
# ДРК (Конго), Исходное количество тексков: 215 шт., оставшееся 60 шт.
# Буркина-Фасо, Исходное количество тексков: 175 шт., оставшееся 0 шт.
# Нигер, Исходное количество тексков: 64 шт., оставшееся 1 шт.
# Мали, Исходное количество тексков: 230 шт., оставшееся 74 шт.
# Сенегал, Исходное количество тексков: 110 шт., оставшееся 108 шт.
# Египет, Исходное количество тексков: 207 шт., оставшееся 12 шт.
# Гвинея, Исходное количество тексков: 93 шт., оставшееся 88 шт.
# Венесуэла, Исходное количество тексков: 116 шт., оставшееся 108 шт.
# Алжир, Исходное количество тексков: 108 шт., оставшееся 92 шт.
# Зимбабве, Исходное количество тексков: 179 шт., оставшееся 149 шт.
# Тунис, Исходное количество тексков: 120 шт., оставшееся 95 шт.
# Боливия, Исходное количество тексков: 102 шт., оставшееся 82 шт.
# Бразилия, Исходное количество тексков: 211 шт., оставшееся 95 шт.
# ЮАР, Исходное количество тексков: 45 шт., оставшееся 1 шт.
# Бурунди, Исходное количество тексков: 70 шт., оставшееся 60 шт.
# Руанда, Исходное количество тексков: 199 шт., оставшееся 56 шт.
# Монголия, Исходное количество тексков: 82 шт., оставшееся 58 шт.
# Пакистан, Исходное количество тексков: 221 шт., оставшееся 124 шт.
# Чили, Исходное количество тексков: 78 шт., оставшееся 59 шт.
# Бангладеш, Исходное количество тексков: 113 шт., оставшееся 84 шт.
# Бенин, Исходное количество тексков: 153 шт., оставшееся 53 шт.
# Габон, Исходное количество тексков: 76 шт., оставшееся 57 шт.
# Лаос, Исходное количество тексков: 206 шт., оставшееся 123 шт.
# Чад, Исходное количество тексков: 213 шт., оставшееся 93 шт.
# Кения, Исходное количество тексков: 133 шт., оставшееся 100 шт.
# Индонезия, Исходное количество тексков: 89 шт., оставшееся 30 шт.
# Иордания, Исходное количество тексков: 209 шт., оставшееся 55 шт.
# Ирак, Исходное количество тексков: 63 шт., оставшееся 11 шт.
# Камбоджа, Исходное количество тексков: 68 шт., оставшееся 44 шт.
# Куба, Исходное количество тексков: 212 шт., оставшееся 116 шт.
# Таиланд, Исходное количество тексков: 73 шт., оставшееся 54 шт.
# Уругвай, Исходное количество тексков: 43 шт., оставшееся 17 шт.
# Камерун, Исходное количество тексков: 208 шт., оставшееся 117 шт.
# Мадагаскар, Исходное количество тексков: 96 шт., оставшееся 78 шт.
# Мозамбик, Исходное количество тексков: 204 шт., оставшееся 87 шт.
# Япония, Исходное количество тексков: 226 шт., оставшееся 200 шт.
# Мексика, Исходное количество тексков: 1009 шт., оставшееся 701 шт.
# ОАЭ, Исходное количество тексков: 347 шт., оставшееся 100 шт.
# Саудовская Аравия, Исходное количество тексков: 206 шт., оставшееся 4 шт.
# Йемен, Исходное количество тексков: 208 шт., оставшееся 98 шт.
# Пакистан, Исходное количество тексков: 221 шт., оставшееся 124 шт.
# Лаос, Исходное количество тексков: 206 шт., оставшееся 123 шт.
# Республика Конго, Исходное количество тексков: 201 шт., оставшееся 28 шт.

# %%
import pandas as pd
import seaborn as sns
plt.figure(figsize=(12, 6))
ax = sns.barplot(x="Country", y="Confidence", data=df)

ax.tick_params(axis='x', labelrotation=90)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# ax.set_xticks(ticks=ax.get_xticks(), labels=ax.get_xticklabels(), rotation=45, ha='right')
plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(x="Country", y="Confidence", data=df[(df['Country']==df['Predict_class'])])

ax.tick_params(axis='x', labelrotation=90)
# ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
# ax.set_xticks(ticks=ax.get_xticks(), labels=ax.get_xticklabels(), rotation=45, ha='right')
plt.show()

# %%
import sys
import os
import hashlib

def chunk_reader(fobj, chunk_size=1024):
    """Generator that reads a file in chunks of bytes"""
    while True:
        chunk = fobj.read(chunk_size)
        if not chunk:
            return
        yield chunk

def check_for_duplicates(paths, hash=hashlib.sha1):
    hashes = {}
    #print (os.listdir(paths))        
    for filename in [name for name in sorted(os.listdir(paths)) ]:
        full_path = os.path.join(paths, filename)
        hashobj = hash()
        for chunk in chunk_reader(open(full_path, 'rb')):
            hashobj.update(chunk)
        file_id = (hashobj.digest(), os.path.getsize(full_path))
        duplicate = hashes.get(file_id, None)
        if duplicate:
            print ("Duplicate found: %s and %s" % (full_path, duplicate))
            os.remove(full_path)
        else:
            hashes[file_id] = full_path

# %%
               
for country in CL:
    path = os.path.join('./datasets/', "Tass_Dataset_6", country)
    #remove_duplicates(path)
    check_for_duplicates(path)
# Out:
# Duplicate found: ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi1673_5_telegram.txt and ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi1673_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi1821_4_telegram.txt and ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi1821_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi2021_3_telegram.txt and ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi2021_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi2784_4_telegram.txt and ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi2784_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi_0_telegram.txt and ./datasets/Tass_Dataset_6\Afganistan\@afgbezparandzhi2847_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\Afganistan\@mideastr6375_0_telegram.txt and ./datasets/Tass_Dataset_6\Afganistan\@arabstatesofgulf2187_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@asiatica_ru2100_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@asiatica_ru2100_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@asiatica_ru2100_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@asiatica_ru2100_4_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@asiatica_ru2165_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@asiatica_ru2165_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@asiatica_ru2376_4_telegram.txt and ./datasets/Tass_Dataset_6\China\@asiatica_ru2376_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1069_4_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1069_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1111_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1111_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1175_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1175_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1240_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1240_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1346_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1346_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1430_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1430_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1430_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1430_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1665_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1665_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1665_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1665_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1686_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1686_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1707_4_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1707_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1772_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1772_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1793_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1793_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1814_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1814_4_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1942_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1942_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1942_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1942_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon1985_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon1985_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon2048_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon2048_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon2069_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon2069_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon2132_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon0_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon759_7_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon759_4_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon920_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon920_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon941_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon941_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon963_9_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon963_10_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon985_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon985_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@awaken_dragon985_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@awaken_dragon985_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@china80s2364_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@china80s2364_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@china80s2830_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@china80s2830_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@china80s3049_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@china80s3049_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@china80s3873_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@china80s3873_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@infantmilitario137570_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@infantmilitario137566_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@prchand8438_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@prchand8438_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@prchand8753_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@prchand8746_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@prchand8809_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@prchand8795_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@prchand9389_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@prchand9378_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info11505_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info11505_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info11631_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info11631_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info11652_4_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info11652_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info11652_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info11652_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12285_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12285_4_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12306_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12306_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12442_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12440_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12463_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12461_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12485_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12483_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12590_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12588_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12611_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12609_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12698_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12696_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12785_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12783_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@raspp_info12809_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@raspp_info12807_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129615_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129615_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129804_4_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129804_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129870_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129783_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129912_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129891_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129912_6_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129912_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129912_7_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129912_4_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129954_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129783_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130017_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129804_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130126_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129804_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130147_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130126_3_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130252_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130252_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130257_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130257_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130278_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130278_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130278_6_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130278_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130294_0_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130231_0_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130294_1_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130231_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130299_7_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130299_6_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130341_3_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130341_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130341_5_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130341_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130341_6_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130341_2_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130487_6_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru129891_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130499_7_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130320_4_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130541_2_telegram.txt and ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru130541_1_telegram.txt
# Duplicate found: ./datasets/Tass_Dataset_6\China\@xinhua_news_agency_ru